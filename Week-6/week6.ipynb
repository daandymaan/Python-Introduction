# %% [markdown]
# # Week 6
#
# This week will dive into classes objects and *some* object oriented principles (There is a quite a few to go over but these are stuff that you can pick up as you go along)
#
# Classes are code representations of real world objects, they have virtualise an object so it can be used repetiviely and then it is self contained with everything it needs
#
# Classes are called objects (Terms can be interchangeable)
#
# Classes have two many components, attributes and methods (Functions)

# %% [markdown]
# Here is an example of a simple class of a Vehicle
# I would suggest playing around with this class to fully get to grips with how it works
# 1. Try making your own instance of the class (Similiar to massey and toyota) and using some of the methods
# 2. Try adding a new attribute (Similiar to vehicleType, brand, price, speed etc) an example could be license plate or owner
# 3. Try adding a new method (Similiar to drive etc) an example could be service / upgrade which increases the value of the vehicle or even breakdown which drastically decreases value
#
# Just a note, classes will be especially useful for each of the apparatus needed for your experiments, each apparatus could have a class with its predefined attributes (Flow rate wattage etc)
# you could almost recreate the experiment virtually through python further down the line

# %%
#This is the definition of a class similiar to how you define a function except no brackets
#CLASSES SHOULD ALWAYS START WITH A CAPTIAL
class Vehicle:
    #This is the init of the function, this is called the constructor, it must always contain the keyword 'self'
    #These attributes are created when the object is first created
    def __init__(self, vehicleType, brand, price, speed, lawAF):
        #stating the object its selfd is going to have a variable called vehicle type which is equal to the user input.
        self.vehicleType = vehicleType
        self.brand = brand
        self.price = price
        self.speed = speed
        self.lawAF = lawAF

        #This is an attribute that is not created by the user
        # Can set variables by the object
        self.distance = 0
        self.fuel = 100


    #Classes can also have their own specified functions (Must also contain self)
    def drive(self):
        print(self.brand)
        if(self.fuel > 10):
            #print("~~~~~Driving~~~~~~")
            self.distance += self.speed
            self.fuel -= ((self.speed * 2) * 0.1)

        def refuel(self):
            print(self.brand)
            print("=====REFUELING-----")
            self.fuel = 100

        if(self.fuel < 10):
            print("Car running low on fuel pls refuel")
            refuel(self)
            
        if(self.distance > 100):
            print("Driven over 100km !!")


    def displayCarDetails(self):
        print("\nVEHICLE TYPE:\t", self.vehicleType, "\nBRAND:\t", self.brand + "\nPRICE:\t", self.price, "\t\nDISTANCE TRAVELED:\t", self.distance, "KM\t\nCURRENT FUEL:\t", self.fuel, "\nLaw attention factor: \t:", self.lawAF, "%\n")

    def unwantedincident(self):
        print(self.brand)
        if(self.distance * self.lawAF == 360):
            print("Ruh Roh, we got pulled over!")
        #To make this really useful would need a second distance attribute (i.e. dist form last incident)
        if(self.distance >= 800):
            print("Sheeeesh, that's a lotta damage")
            self.price = self.price*0.8
            self.speed = self.speed*0.9

    def factorAccelerator(self):
        toyota.displayCarDetails()
        massey.displayCarDetails()
        porshe.displayCarDetails()
        toyota.drive()
        toyota.drive()
        toyota.drive()
        toyota.drive()
        toyota.unwantedincident()
        porshe.drive()
        porshe.drive()
        porshe.unwantedincident()
        porshe.drive()
        porshe.drive()
        porshe.drive()
        porshe.unwantedincident()
        massey.drive()
        massey.drive()
        massey.drive()
        massey.drive()
        massey.drive()
        massey.drive()
        massey.drive()
        massey.unwantedincident()
        toyota.displayCarDetails()
        massey.displayCarDetails()
        porshe.displayCarDetails()


        


#When creating an instance of the class be sure to confirm that the values you are inputting match the ones specified in the init function 
# here we are initiation a vehivle with name, brand, price and speed referring to def_init_(self, vehivle type, brand,speed,price) (dont repeat self)
toyota = Vehicle("Car", "Toyota", 23000, 120, 10)
massey = Vehicle("Tractor", "Massey Ferguson", 45000, 40, 36)
porshe = Vehicle("Race Car", "Porshe", 125002, 250, 85)

toyota.factorAccelerator()
massey.factorAccelerator()
porshe.factorAccelerator()
 
# toyota.displayCarDetails()
# massey.displayCarDetails()
# porshe.displayCarDetails()

# toyota.drive()
# toyota.drive()
# porshe.drive()
# massey.drive()
# massey.drive()

# toyota.displayCarDetails()
# massey.displayCarDetails()
# porshe.displayCarDetails()

# toyota.refuel()
# massey.refuel()
# porshe.refuel()

# toyota.displayCarDetails()
# massey.displayCarDetails()
# porshe.displayCarDetails()
# Out:
# VEHICLE TYPE:	 Car
# BRAND:	 Toyota
# PRICE:	 23000
# DISTANCE TRAVELED:	 0 KM
# CURRENT FUEL:	 100
# Law attention factor: 	: 10 %
#
#
# VEHICLE TYPE:	 Tractor
# BRAND:	 Massey Ferguson
# PRICE:	 45000
# DISTANCE TRAVELED:	 0 KM
# CURRENT FUEL:	 100
# Law attention factor: 	: 36 %
#
#
# VEHICLE TYPE:	 Race Car
# BRAND:	 Porshe
# PRICE:	 125002
# DISTANCE TRAVELED:	 0 KM
# CURRENT FUEL:	 100
# Law attention factor: 	: 85 %
#
# Toyota
# Driven over 100km !!
# Toyota
# Driven over 100km !!
# Toyota
# Driven over 100km !!
# Toyota
# Car running low on fuel pls refuel
# Toyota
# =====REFUELING-----
# Driven over 100km !!
# Toyota
# Porshe
# Driven over 100km !!
# Porshe
# Car running low on fuel pls refuel
# Porshe
# =====REFUELING-----
# Driven over 100km !!
# Porshe
# Porshe
# Driven over 100km !!
# Porshe
# Car running low on fuel pls refuel
# Porshe
# =====REFUELING-----
# Driven over 100km !!
# Porshe
# Driven over 100km !!
# Porshe
# Sheeeesh, that's a lotta damage
# Massey Ferguson
# Massey Ferguson
# Massey Ferguson
# Driven over 100km !!
# Massey Ferguson
# Driven over 100km !!
# Massey Ferguson
# Driven over 100km !!
# Massey Ferguson
# Driven over 100km !!
# Massey Ferguson
# Driven over 100km !!
# Massey Ferguson
#
# VEHICLE TYPE:	 Car
# BRAND:	 Toyota
# PRICE:	 23000
# DISTANCE TRAVELED:	 480 KM
# CURRENT FUEL:	 100
# Law attention factor: 	: 10 %
#
#
# VEHICLE TYPE:	 Tractor
# BRAND:	 Massey Ferguson
# PRICE:	 45000
# DISTANCE TRAVELED:	 280 KM
# CURRENT FUEL:	 44.0
# Law attention factor: 	: 36 %
#
#
# VEHICLE TYPE:	 Race Car
# BRAND:	 Porshe
# PRICE:	 100001.6
# DISTANCE TRAVELED:	 1250 KM
# CURRENT FUEL:	 50.0
# Law attention factor: 	: 85 %
#
#
# VEHICLE TYPE:	 Car
# BRAND:	 Toyota
# PRICE:	 23000
# DISTANCE TRAVELED:	 480 KM
# CURRENT FUEL:	 100
# Law attention factor: 	: 10 %
#
#
# VEHICLE TYPE:	 Tractor
# BRAND:	 Massey Ferguson
# PRICE:	 45000
# DISTANCE TRAVELED:	 280 KM
# CURRENT FUEL:	 44.0
# Law attention factor: 	: 36 %
#
#
# VEHICLE TYPE:	 Race Car
# BRAND:	 Porshe
# PRICE:	 100001.6
# DISTANCE TRAVELED:	 1250 KM
# CURRENT FUEL:	 50.0
# Law attention factor: 	: 85 %
#
# Toyota
# Driven over 100km !!
# Toyota
# Driven over 100km !!
# Toyota
# Driven over 100km !!
# Toyota
# Car running low on fuel pls refuel
# Toyota
# =====REFUELING-----
# Driven over 100km !!
# Toyota
# Sheeeesh, that's a lotta damage
# Porshe
# Car running low on fuel pls refuel
# Porshe
# =====REFUELING-----
# Driven over 100km !!
# Porshe
# Driven over 100km !!
# Porshe
# Sheeeesh, that's a lotta damage
# Porshe
# Driven over 100km !!
# Porshe
# Car running low on fuel pls refuel
# Porshe
# =====REFUELING-----
# Driven over 100km !!
# Porshe
# Driven over 100km !!
# Porshe
# Sheeeesh, that's a lotta damage
# Massey Ferguson
# Driven over 100km !!
# Massey Ferguson
# Driven over 100km !!
# Massey Ferguson
# Driven over 100km !!
# Massey Ferguson
# Driven over 100km !!
# Massey Ferguson
# Car running low on fuel pls refuel
# Massey Ferguson
# =====REFUELING-----
# Driven over 100km !!
# Massey Ferguson
# Driven over 100km !!
# Massey Ferguson
# Driven over 100km !!
# Massey Ferguson
#
# VEHICLE TYPE:	 Car
# BRAND:	 Toyota
# PRICE:	 18400.0
# DISTANCE TRAVELED:	 960 KM
# CURRENT FUEL:	 100
# Law attention factor: 	: 10 %
#
#
# VEHICLE TYPE:	 Tractor
# BRAND:	 Massey Ferguson
# PRICE:	 45000
# DISTANCE TRAVELED:	 560 KM
# CURRENT FUEL:	 84.0
# Law attention factor: 	: 36 %
#
#
# VEHICLE TYPE:	 Race Car
# BRAND:	 Porshe
# PRICE:	 64001.02400000001
# DISTANCE TRAVELED:	 2307.5 KM
# CURRENT FUEL:	 59.5
# Law attention factor: 	: 85 %
#
#
# VEHICLE TYPE:	 Car
# BRAND:	 Toyota
# PRICE:	 18400.0
# DISTANCE TRAVELED:	 960 KM
# CURRENT FUEL:	 100
# Law attention factor: 	: 10 %
#
#
# VEHICLE TYPE:	 Tractor
# BRAND:	 Massey Ferguson
# PRICE:	 45000
# DISTANCE TRAVELED:	 560 KM
# CURRENT FUEL:	 84.0
# Law attention factor: 	: 36 %
#
#
# VEHICLE TYPE:	 Race Car
# BRAND:	 Porshe
# PRICE:	 64001.02400000001
# DISTANCE TRAVELED:	 2307.5 KM
# CURRENT FUEL:	 59.5
# Law attention factor: 	: 85 %
#
# Toyota
# Driven over 100km !!
# Toyota
# Driven over 100km !!
# Toyota
# Driven over 100km !!
# Toyota
# Driven over 100km !!
# Toyota
# Sheeeesh, that's a lotta damage
# Porshe
# Driven over 100km !!
# Porshe
# Car running low on fuel pls refuel
# Porshe
# =====REFUELING-----
# Driven over 100km !!
# Porshe
# Sheeeesh, that's a lotta damage
# Porshe
# Driven over 100km !!
# Porshe
# Driven over 100km !!
# Porshe
# Car running low on fuel pls refuel
# Porshe
# =====REFUELING-----
# Driven over 100km !!
# Porshe
# Sheeeesh, that's a lotta damage
# Massey Ferguson
# Driven over 100km !!
# Massey Ferguson
# Driven over 100km !!
# Massey Ferguson
# Driven over 100km !!
# Massey Ferguson
# Driven over 100km !!
# Massey Ferguson
# Driven over 100km !!
# Massey Ferguson
# Driven over 100km !!
# Massey Ferguson
# Driven over 100km !!
# Massey Ferguson
# Sheeeesh, that's a lotta damage
#
# VEHICLE TYPE:	 Car
# BRAND:	 Toyota
# PRICE:	 14720.0
# DISTANCE TRAVELED:	 1392.0 KM
# CURRENT FUEL:	 13.600000000000001
# Law attention factor: 	: 10 %
#
#
# VEHICLE TYPE:	 Tractor
# BRAND:	 Massey Ferguson
# PRICE:	 36000.0
# DISTANCE TRAVELED:	 840 KM
# CURRENT FUEL:	 28.0
# Law attention factor: 	: 36 %
#
#
# VEHICLE TYPE:	 Race Car
# BRAND:	 Porshe
# PRICE:	 40960.65536000001
# DISTANCE TRAVELED:	 3164.0750000000003 KM
# CURRENT FUEL:	 100
# Law attention factor: 	: 85 %

# %% [markdown]
# Another example of classes is using inheritance, this is as it sounds just inheriting the values from a 'parent' class the best example I can show is below
#
#
# It will also discuss method overiding and even the default method overiding

# %%
class Person():
    def __init__(self, name, age, profession):
        self.name = name
        self.age = age
        self.profession = profession

    def __str__(self):
        return "Hi my name is " + self.name + " and I am "+ str(self.age)  + " I work as " +  self.profession

    def speak(self):
        print("Hi my name is " , self.name, " and I am ", self.age , " I work as a", self.profession)

    def __add__(self, other):
        return "b u r r i t o " 


class Doctor(Person):
    def __init__(self, name, age):
        self.profession = "Doctor"
        super().__init__(name, age, self.profession)
        self.salary = 72000
    def showSalary(self):
        print("SALARY:"+ self.salary)

class Student(Person):
    def __init__(self, name, age, module, gradYear):
        self.profession = "Student"
        super().__init__(name, age, self.profession)
        self.module = module 
        self.gradYear = gradYear


    # This here is called method / function overidding, its very useful if you want to make ammedments to an inherited function
    def speak(self):
        print("Hi my name is " , self.name, " and I am student (Whatsuppp!!) and I am in ", self.module)

# %%
personExample = Person("Davey Jones", 34, "Sailor")
doctorExample = Doctor("Dr. Ralph Stones", 49)
studentExample = Student("Derek Landy", 19, "Literature", 2024)

personExample.speak()
doctorExample.speak()
studentExample.speak()

print("\n\n\n")
# Out:
# Hi my name is  Davey Jones  and I am  34  I work as a Sailor
# Hi my name is  Dr. Ralph Stones  and I am  49  I work as a Doctor
# Hi my name is  Derek Landy  and I am student (Whatsuppp!!) and I am in  Literature

# %% [markdown]
# # Cool things
# If you look above you can see that we modified a few default functions, these are denoted with two underscores before the method name
# Default functions are actually inheritted functions from the master class which all objects inherit from
# You can really make fucky wucky code with modifiying these functions I wouldn't suggest doing it unless it's really neccessary
# The __str__ method is pretty much the only one people change just it easier

# %%
personList = [personExample, doctorExample, studentExample]

for person in personList:
    print(person)

print("\n\n\n")

print(personExample + studentExample)
# Out:
# Hi my name is Davey Jones and I am 34 I work as Sailor
# Hi my name is Dr. Ralph Stones and I am 49 I work as Doctor
# Hi my name is Derek Landy and I am 19 I work as Student
#
#
#
#
# b u r r i t o

# %% [markdown]
# # No exercise ... kinda
# No real exercise this week as this is kinda the stuff to just play around with, I could say make a school system yada yada yada but I feel this is more the week you play around with stuff create classes from some objects (Maybe fruits or drinks at a bar)
#
# Lemme know if you get stuck
